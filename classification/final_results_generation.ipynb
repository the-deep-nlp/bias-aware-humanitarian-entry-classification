# %%
from results_analysis import (
    get_classification_results,
    generate_tagwise_results,
)

folder_name = 'results'

# %%
classification_results = get_classification_results(
    llm_models=["mbert", "xlm-r", "humbert"],
    training_setups=["no_debiasing", "counterfactual_debiasing"],
    training_architectures=["base_architecture", "multiabel_architecture"],
    folder_name=folder_name,
)
classification_results.round(2)
# Out:
#                Measurement      LLM      Model  sectors precision  \
# 0   Classification Results    mbert  Base-Base               0.75
# 1   Classification Results    mbert  OURS-Base               0.76
# 2   Classification Results    mbert   Base-CDA               0.76
# 3   Classification Results    mbert   OURS-CDA               0.76
# 4   Classification Results    xlm-r  Base-Base               0.74
# 5   Classification Results    xlm-r  OURS-Base               0.75
# 6   Classification Results    xlm-r   Base-CDA               0.75
# 7   Classification Results    xlm-r   OURS-CDA               0.75
# 8   Classification Results  humbert  Base-Base               0.76
# 9   Classification Results  humbert  OURS-Base               0.76
# 10  Classification Results  humbert   Base-CDA               0.77
# 11  Classification Results  humbert   OURS-CDA               0.76
#
#     sectors f_score  pillars 1d precision  pillars 1d f_score  \
# 0              0.77                  0.68                0.70
# 1              0.77                  0.68                0.70
# 2              0.76                  0.65                0.68
# 3              0.77                  0.69                0.69
# 4              0.76                  0.70                0.68
# 5              0.77                  0.70                0.69
# 6              0.77                  0.68                0.69
# 7              0.77                  0.70                0.70
# 8              0.78                  0.69                0.70
# 9              0.78                  0.67                0.70
# 10             0.78                  0.69                0.70
# 11             0.79                  0.70                0.70
#
#     subpillars 1d precision  subpillars 1d f_score  pillars 2d precision  \
# 0                      0.51                   0.51                  0.70
# 1                      0.55                   0.53                  0.71
# 2                      0.49                   0.51                  0.69
# 3                      0.54                   0.52                  0.70
# 4                      0.48                   0.49                  0.69
# 5                      0.54                   0.53                  0.69
# 6                      0.50                   0.51                  0.69
# 7                      0.52                   0.53                  0.69
# 8                      0.52                   0.53                  0.70
# 9                      0.54                   0.55                  0.70
# 10                     0.57                   0.54                  0.71
# 11                     0.55                   0.54                  0.69
#
#     pillars 2d f_score  subpillars 2d precision  subpillars 2d f_score  \
# 0                 0.69                     0.54                   0.48
# 1                 0.70                     0.56                   0.52
# 2                 0.69                     0.48                   0.47
# 3                 0.70                     0.47                   0.48
# 4                 0.68                     0.51                   0.47
# 5                 0.70                     0.51                   0.51
# 6                 0.70                     0.51                   0.48
# 7                 0.70                     0.53                   0.52
# 8                 0.70                     0.52                   0.50
# 9                 0.70                     0.50                   0.51
# 10                0.71                     0.55                   0.51
# 11                0.71                     0.55                   0.52
#
#     Avg precision  Avg f_score
# 0            0.71         0.72
# 1            0.72         0.72
# 2            0.70         0.71
# 3            0.72         0.72
# 4            0.71         0.71
# 5            0.71         0.72
# 6            0.71         0.72
# 7            0.72         0.72
# 8            0.72         0.73
# 9            0.71         0.73
# 10           0.72         0.73
# 11           0.72         0.73

# %%
classification_results = get_classification_results(
    llm_models=["mbert", "xlm-r", "humbert"],
    training_setups=["no_debiasing", "counterfactual_debiasing"],
    training_architectures=["base_architecture"],
    folder_name=folder_name,
)
classification_results.round(2)
# Out:
#               Measurement      LLM      Model  sectors precision  \
# 0  Classification Results    mbert  Base-Base               0.75
# 1  Classification Results    mbert   Base-CDA               0.76
# 2  Classification Results    xlm-r  Base-Base               0.74
# 3  Classification Results    xlm-r   Base-CDA               0.75
# 4  Classification Results  humbert  Base-Base               0.76
# 5  Classification Results  humbert   Base-CDA               0.77
#
#    sectors f_score  pillars 1d precision  pillars 1d f_score  \
# 0             0.77                  0.68                0.70
# 1             0.76                  0.65                0.68
# 2             0.76                  0.70                0.68
# 3             0.77                  0.68                0.69
# 4             0.78                  0.69                0.70
# 5             0.78                  0.69                0.70
#
#    subpillars 1d precision  subpillars 1d f_score  pillars 2d precision  \
# 0                     0.51                   0.51                  0.70
# 1                     0.49                   0.51                  0.69
# 2                     0.48                   0.49                  0.69
# 3                     0.50                   0.51                  0.69
# 4                     0.52                   0.53                  0.70
# 5                     0.57                   0.54                  0.71
#
#    pillars 2d f_score  subpillars 2d precision  subpillars 2d f_score  \
# 0                0.69                     0.54                   0.48
# 1                0.69                     0.48                   0.47
# 2                0.68                     0.51                   0.47
# 3                0.70                     0.51                   0.48
# 4                0.70                     0.52                   0.50
# 5                0.71                     0.55                   0.51
#
#    Avg precision  Avg f_score
# 0           0.71         0.72
# 1           0.70         0.71
# 2           0.71         0.71
# 3           0.71         0.72
# 4           0.72         0.73
# 5           0.72         0.73

# %%
llm_models = ["mbert", "xlm-r", "humbert"]
training_setups = ["no_debiasing", "counterfactual_debiasing"]
protected_attributes = ["gender", "country"]
visualized_methods = [
    "probability_discrepancy",
]
training_architectures = ["base_architecture", "multiabel_architecture"]

tagwise_results_df = generate_tagwise_results(
    llm_models,
    training_setups,
    training_architectures,
    protected_attributes,
    visualized_methods,
    folder_name,
    save_vizus=True,
)
# Out:
# 100%|██████████| 24/24 [15:54<00:00, 39.79s/it]

# %%
tagwise_results_df
# Out:
#        base_kw  median_shift original->couterfactual  \
# 0      Neutral      0.000085         Neutral->Female
# 1       Female     -0.000085         Female->Neutral
# 2      Neutral      0.112473         Neutral->Female
# 3       Female     -0.112473         Female->Neutral
# 4      Neutral     -0.057665         Neutral->Female
# ..         ...           ...                     ...
# 139  Venezuela      0.001144        Venezuela->Syria
# 140      Syria     -0.000214        Syria->Venezuela
# 141  Venezuela      0.000214        Venezuela->Syria
# 142      Syria     -0.000002        Syria->Venezuela
# 143  Venezuela      0.000002        Venezuela->Syria
#
#                                           tag bias_attribute  \
# 0    first_level_tags->pillars_1d->Casualties         gender
# 1    first_level_tags->pillars_1d->Casualties         gender
# 2       first_level_tags->pillars_1d->Context         gender
# 3       first_level_tags->pillars_1d->Context         gender
# 4      first_level_tags->pillars_1d->Covid-19         gender
# ..                                        ...            ...
# 139     first_level_tags->sectors->Protection        country
# 140        first_level_tags->sectors->Shelter        country
# 141        first_level_tags->sectors->Shelter        country
# 142           first_level_tags->sectors->Wash        country
# 143           first_level_tags->sectors->Wash        country
#
#                  bias_method   training_architecture  \
# 0    probability_discrepancy       base_architecture
# 1    probability_discrepancy       base_architecture
# 2    probability_discrepancy       base_architecture
# 3    probability_discrepancy       base_architecture
# 4    probability_discrepancy       base_architecture
# ..                       ...                     ...
# 139  probability_discrepancy  multiabel_architecture
# 140  probability_discrepancy  multiabel_architecture
# 141  probability_discrepancy  multiabel_architecture
# 142  probability_discrepancy  multiabel_architecture
# 143  probability_discrepancy  multiabel_architecture
#
#                 trainig_setup llm_model
# 0                no_debiasing     mbert
# 1                no_debiasing     mbert
# 2                no_debiasing     mbert
# 3                no_debiasing     mbert
# 4                no_debiasing     mbert
# ..                        ...       ...
# 139  counterfactual_debiasing   humbert
# 140  counterfactual_debiasing   humbert
# 141  counterfactual_debiasing   humbert
# 142  counterfactual_debiasing   humbert
# 143  counterfactual_debiasing   humbert
#
# [3456 rows x 9 columns]

# %%
mapping_training_type_to_name = {
    "no_debiasing": "Base",
    "counterfactual_debiasing": "CDA",
}

mapping_training_architecture2name = {
    "multiabel_architecture": "OURS",
    "base_architecture": "Base",
}

# %%
import pandas as pd
from tqdm import tqdm

results_df_one_run = pd.DataFrame()
# with tqdm(
#     total=len(llm_models)
#     * len(training_setups)
#     * len(protected_attributes)
#     * len(visualized_methods)
#     * len(training_architectures)
# ) as pbar:
for llm_model in llm_models:
    for training_setup in training_setups:
        for training_architecture in training_architectures:
            for bias_method in visualized_methods:
                bias_results = {}
                for bias_attribute in protected_attributes:
                    df_one_result = tagwise_results_df[
                        (tagwise_results_df.llm_model == llm_model)
                        & (tagwise_results_df.trainig_setup == training_setup)
                        & (
                            tagwise_results_df.training_architecture
                            == training_architecture
                        )
                        & (tagwise_results_df.bias_method == bias_method)
                        & (tagwise_results_df.bias_attribute == bias_attribute)
                    ]
                    #print(df_one_result.shape[0])
                    n_keywords = df_one_result["original->couterfactual"].nunique()
                    assert n_keywords == 6, f"problem, {n_keywords} total keywords found., {df_one_result['original->couterfactual'].unique()}"

                    bias_results[bias_attribute] = (
                        df_one_result.median_shift.abs().sum() / n_keywords
                    )

                metrics_one_row = {
                    "Measurement": "Probability Discepancy",
                    "LLM": llm_model,
                    "Model": f"{mapping_training_architecture2name[training_architecture]}-{mapping_training_type_to_name[training_setup]}",
                }
                metrics_one_row.update(bias_results)

                results_df_one_run = results_df_one_run.append(
                    metrics_one_row, ignore_index=True
                )

results_df_one_run[["Measurement", "LLM", "Model", "gender", "country"]]
# Out:
#                Measurement      LLM      Model    gender   country
# 0   Probability Discepancy    mbert  Base-Base  0.569610  9.794427
# 1   Probability Discepancy    mbert  OURS-Base  0.475864  6.371959
# 2   Probability Discepancy    mbert   Base-CDA  0.018834  0.174317
# 3   Probability Discepancy    mbert   OURS-CDA  0.015942  0.123466
# 4   Probability Discepancy    xlm-r  Base-Base  0.670163  8.685331
# 5   Probability Discepancy    xlm-r  OURS-Base  0.397679  3.665823
# 6   Probability Discepancy    xlm-r   Base-CDA  0.046608  0.141070
# 7   Probability Discepancy    xlm-r   OURS-CDA  0.013046  0.112094
# 8   Probability Discepancy  humbert  Base-Base  0.708054  8.367259
# 9   Probability Discepancy  humbert  OURS-Base  0.284586  6.516957
# 10  Probability Discepancy  humbert   Base-CDA  0.016938  0.112601
# 11  Probability Discepancy  humbert   OURS-CDA  0.008507  0.125794

# %%
for i, row in results_df_one_run.round(2).iterrows():
    print(" & ".join([str(row[col]) for col in ["LLM", "Model", "gender", "country"]]))
# Out:
# mbert & Base-Base & 0.57 & 9.79
# mbert & OURS-Base & 0.48 & 6.37
# mbert & Base-CDA & 0.02 & 0.17
# mbert & OURS-CDA & 0.02 & 0.12
# xlm-r & Base-Base & 0.67 & 8.69
# xlm-r & OURS-Base & 0.4 & 3.67
# xlm-r & Base-CDA & 0.05 & 0.14
# xlm-r & OURS-CDA & 0.01 & 0.11
# humbert & Base-Base & 0.71 & 8.37
# humbert & OURS-Base & 0.28 & 6.52
# humbert & Base-CDA & 0.02 & 0.11
# humbert & OURS-CDA & 0.01 & 0.13
